# %%
# 直接输出
print("Hello World")
print(100)

a = 1
print(a)

name = 'lisi'
print("My name is", name)
# Out:
# Hello World
# 100
# 1
# My name is lisi

# %%
# 格式化输出
name = 'zhangsan'
age = 18

# 直接输出的方法
print("My name is", name, "and i am", age, "years old.")

# 格式化输出的方法
print("My name is %s and i am %d years old." %(name, age))

weight = 70.123456789
print("My name is %s and my weight is %f" %(name, weight))

# m.n
# m是用来控制输出数据的所占长度
# n是用来控制输出数据的精度问题
print("My name is %s and my weight is %5f" %(name, weight))
print("My name is %s and my weight is %10f" %(name, weight))
print("My name is %s and my weight is %.2f" %(name, weight))
print("My name is %s and my weight is %.5f" %(name, weight))
# Out:
# My name is zhangsan and i am 18 years old.
# My name is zhangsan and i am 18 years old.
# My name is zhangsan and my weight is 70.123457
# My name is zhangsan and my weight is 70.123457
# My name is zhangsan and my weight is  70.123457
# My name is zhangsan and my weight is 70.12
# My name is zhangsan and my weight is 70.12346

# %%
# format方法，使用{}来占位
name = 'zhangsan'
age = 18
print("My name is {} and i am {} years old" .format(name, age))
print("My name is {} and i am {} years old" .format(age, name))

weight = 70.123456789012324567890
print("My name is {} and my weight is {:.2f}" .format(name, weight))
# Out:
# My name is zhangsan and i am 18 years old
# My name is 18 and i am zhangsan years old
# My name is zhangsan and my weight is 70.12

# %%
# f-string，使用{}占位，并直接插入表达式
name = 'zhangsan'
age = 18
print(f"My name is {name} and i am {age + 1} years old")

weight = 70.12345678
print(f"My name is {name} and my weight is {weight:.2f}")
# Out:
# My name is zhangsan and i am 19 years old
# My name is zhangsan and my weight is 70.12

# %%
# 使用input进行输入
# name = input("请输入你的名字：")
# print(name)

a = input("请输入加数：")
b = input("请输入被加数：")
c = a + b
print(c)
# Out:
# 请输入加数： 1
# 请输入被加数： 2
# 12
