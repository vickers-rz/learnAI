# %%
print("123")
print("123")
a = 1
b = 2
if a < b:
    print("a < b")
    print("a < b")
print(123+123+123+123+123+123+123+123+123+123+123+123+\
     123+123+123+123)
# Out:
# 123
# 123
# a < b
# a < b
# 1968
