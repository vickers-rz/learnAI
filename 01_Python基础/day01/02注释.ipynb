# %%
# print("Hello World1")

# 这是一个打印语句，打印的内容是Hello World2
print("Hello World2")
# Out:
# Hello World2

# %%
# 这是一个多行注释的例子
print("Hello World1")
'''
print("Hello World2")
print("Hello World3")
print("Hello World4")
print("Hello World5")
'''
print("Hello World6")
